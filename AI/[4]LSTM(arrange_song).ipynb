# %% [markdown]
# #Arrange the song using RNN(LSTM)
# ### 신경망으로 악보 학습 후 새로운 곡 생성.
# #### ABC표기(계이름, 박자: 2채널)를 수행한 데이터를 이용하겠습니다.
# #### 분류 문제로 해결하였습니다.

# %% [markdown]
# ##### 먼저, 데이터를 준비하겠습니다.

# %%
import music21 #music21 Library. Can play the marked data

# "Little Star". C: do, D: re / 2: half note, 4: note
little_star="tinynotation: 4/4 c4 c4 g4 g4 a4 a4 g2 f4 f4 e4 e4 d4 d4 c2 g4 g4 f4 f4 e4 e4 d2 g4 g4 f4 f4 e4 e4 d2 c4 c4 g4 g4 a4 a4 g2 f4 f4 e4 e4 d4 d4 c2" #나중에 분할을 위해 ' '띄어쓰기를 해줍니다.
#music21.converter.parse(little_star).show('mid') #play

# %%
import numpy as np

# 딕셔너리 자료구조로 계이름과 숫자를 변형하는 기준을 세웠습니다.
note2num = {'c':1, 'd':2, 'e':3, 'f':4, 'g':5, 'a':6, 'b':7}
num2note = {1:'c', 2:'d', 3:'e', 4:'f', 5:'g', 6:'a', 7:'b'}

# %%
#abc data -> sequential data
def abc2timeseries(s): #s: little_star
  notes=s.split(' ')[2:]
  seq=[]
  for i in notes: #note: ex)c4
    seq.append([note2num[i[0]], int(i[1])])
  return seq

#sequential data -> abc data
def timeseries2abc(t): #t: ex)14
  s='tinynotation: 4/4'
  for i in t:
    s=s+' '+num2note[i[0]]+str(i[1])
  return s

#sequential data -> training set
def seq2dataset(seq,window,horizon):
  X=[]
  Y=[]
  for i in range(len(seq)-(window+horizon)+1):
    x=seq[i:(i+window)]
    X.append(x)
    y=(seq[i+window+horizon-1])
    Y.append(y)
  return np.array(X), np.array(Y)

# %%
w=8
h=1

seq=abc2timeseries(little_star)
X,Y=seq2dataset(seq,w,h)
#check data
print(X.shape, Y.shape)
print(X[0],Y[0])

#one-hot table
onehot=[[1,2],[2,2],[3,3],[4,2],[5,2],[6,2],[7,2],[1,4],[2,4],[3,4],[4,4],[5,4],[6,4],[7,4],[1,8],[2,8],[3,8],[4,8],[5,8],[6,8],[7,8]]
#label to one-hot
def to_onehot(l): #l: ex)14
  t=[]
  for i in range(len(l)):
    a=np.zeros(len(onehot))
    a[onehot.index(list(l[i]))] = 1.0
    t.append(a)
  return np.array(t)

split=int(len(X)*1.0)
x_train=X[0:split]
y_train=Y[0:split]
y_train=to_onehot(y_train)
# Out:
# (34, 8, 2) (34, 2)
# [[1 4]
#  [1 4]
#  [5 4]
#  [5 4]
#  [6 4]
#  [6 4]
#  [5 2]
#  [4 4]] [4 4]

# %% [markdown]
# ##### 이어서 모델을 설계하고 학습하겠습니다.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM
import tensorflow as tf

#LSTM model
model = Sequential()
model.add(LSTM(units=128, activation='relu', input_shape=x_train[0].shape))
model.add(Dense(y_train.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=200, batch_size=1, verbose=2)
# Out:
# Epoch 1/200
# 34/34 - 2s - loss: 2.8960 - accuracy: 0.1176 - 2s/epoch - 61ms/step
# Epoch 2/200
# 34/34 - 0s - loss: 2.2519 - accuracy: 0.1765 - 200ms/epoch - 6ms/step
# Epoch 3/200
# 34/34 - 0s - loss: 2.0954 - accuracy: 0.2353 - 194ms/epoch - 6ms/step
# Epoch 4/200
# 34/34 - 0s - loss: 2.0146 - accuracy: 0.2353 - 194ms/epoch - 6ms/step
# Epoch 5/200
# 34/34 - 0s - loss: 1.9370 - accuracy: 0.3235 - 169ms/epoch - 5ms/step
# Epoch 6/200
# 34/34 - 0s - loss: 1.8096 - accuracy: 0.2647 - 163ms/epoch - 5ms/step
# Epoch 7/200
# 34/34 - 0s - loss: 1.6456 - accuracy: 0.5000 - 174ms/epoch - 5ms/step
# Epoch 8/200
# 34/34 - 0s - loss: 1.6247 - accuracy: 0.3824 - 150ms/epoch - 4ms/step
# Epoch 9/200
# 34/34 - 0s - loss: 1.5238 - accuracy: 0.4118 - 94ms/epoch - 3ms/step
# Epoch 10/200
# 34/34 - 0s - loss: 1.5418 - accuracy: 0.3824 - 105ms/epoch - 3ms/step
# Epoch 11/200
# 34/34 - 0s - loss: 1.2598 - accuracy: 0.4412 - 117ms/epoch - 3ms/step
# Epoch 12/200
# 34/34 - 0s - loss: 1.3966 - accuracy: 0.4706 - 105ms/epoch - 3ms/step
# Epoch 13/200
# 34/34 - 0s - loss: 1.2223 - accuracy: 0.5000 - 114ms/epoch - 3ms/step
# Epoch 14/200
# 34/34 - 0s - loss: 1.3320 - accuracy: 0.5000 - 115ms/epoch - 3ms/step
# Epoch 15/200
# 34/34 - 0s - loss: 1.2554 - accuracy: 0.4706 - 127ms/epoch - 4ms/step
# Epoch 16/200
# 34/34 - 0s - loss: 1.1948 - accuracy: 0.5294 - 101ms/epoch - 3ms/step
# Epoch 17/200
# 34/34 - 0s - loss: 1.0733 - accuracy: 0.4412 - 112ms/epoch - 3ms/step
# Epoch 18/200
# 34/34 - 0s - loss: 1.1451 - accuracy: 0.5000 - 125ms/epoch - 4ms/step
# Epoch 19/200
# 34/34 - 0s - loss: 1.0645 - accuracy: 0.5588 - 109ms/epoch - 3ms/step
# Epoch 20/200
# 34/34 - 0s - loss: 0.9570 - accuracy: 0.5588 - 126ms/epoch - 4ms/step
# Epoch 21/200
# 34/34 - 0s - loss: 0.9544 - accuracy: 0.6471 - 130ms/epoch - 4ms/step
# Epoch 22/200
# 34/34 - 0s - loss: 0.7961 - accuracy: 0.6176 - 128ms/epoch - 4ms/step
# Epoch 23/200
# 34/34 - 0s - loss: 1.1151 - accuracy: 0.5588 - 124ms/epoch - 4ms/step
# Epoch 24/200
# 34/34 - 0s - loss: 0.7609 - accuracy: 0.7059 - 101ms/epoch - 3ms/step
# Epoch 25/200
# 34/34 - 0s - loss: 0.9266 - accuracy: 0.6471 - 96ms/epoch - 3ms/step
# Epoch 26/200
# 34/34 - 0s - loss: 0.6591 - accuracy: 0.6765 - 107ms/epoch - 3ms/step
# Epoch 27/200
# 34/34 - 0s - loss: 0.6752 - accuracy: 0.7353 - 106ms/epoch - 3ms/step
# Epoch 28/200
# 34/34 - 0s - loss: 0.7782 - accuracy: 0.7059 - 122ms/epoch - 4ms/step
# Epoch 29/200
# 34/34 - 0s - loss: 0.5368 - accuracy: 0.7353 - 104ms/epoch - 3ms/step
# Epoch 30/200
# 34/34 - 0s - loss: 0.6042 - accuracy: 0.7941 - 131ms/epoch - 4ms/step
# Epoch 31/200
# 34/34 - 0s - loss: 0.8105 - accuracy: 0.7647 - 94ms/epoch - 3ms/step
# Epoch 32/200
# 34/34 - 0s - loss: 0.4634 - accuracy: 0.8824 - 99ms/epoch - 3ms/step
# Epoch 33/200
# 34/34 - 0s - loss: 0.4485 - accuracy: 0.8235 - 118ms/epoch - 3ms/step
# Epoch 34/200
# 34/34 - 0s - loss: 0.4048 - accuracy: 0.9118 - 105ms/epoch - 3ms/step
# Epoch 35/200
# 34/34 - 0s - loss: 0.5059 - accuracy: 0.8529 - 96ms/epoch - 3ms/step
# Epoch 36/200
# 34/34 - 0s - loss: 0.6193 - accuracy: 0.7059 - 125ms/epoch - 4ms/step
# Epoch 37/200
# 34/34 - 0s - loss: 0.5496 - accuracy: 0.8235 - 126ms/epoch - 4ms/step
# Epoch 38/200
# 34/34 - 0s - loss: 0.4164 - accuracy: 0.8235 - 115ms/epoch - 3ms/step
# Epoch 39/200
# 34/34 - 0s - loss: 0.3303 - accuracy: 0.8529 - 101ms/epoch - 3ms/step
# Epoch 40/200
# 34/34 - 0s - loss: 0.2375 - accuracy: 0.8824 - 116ms/epoch - 3ms/step
# Epoch 41/200
# 34/34 - 0s - loss: 0.6698 - accuracy: 0.7941 - 124ms/epoch - 4ms/step
# Epoch 42/200
# 34/34 - 0s - loss: 0.4918 - accuracy: 0.7647 - 106ms/epoch - 3ms/step
# Epoch 43/200
# 34/34 - 0s - loss: 0.2188 - accuracy: 0.9412 - 117ms/epoch - 3ms/step
# Epoch 44/200
# 34/34 - 0s - loss: 0.3552 - accuracy: 0.8529 - 101ms/epoch - 3ms/step
# Epoch 45/200
# 34/34 - 0s - loss: 0.1921 - accuracy: 0.9412 - 105ms/epoch - 3ms/step
# Epoch 46/200
# 34/34 - 0s - loss: 0.1591 - accuracy: 0.9412 - 119ms/epoch - 3ms/step
# Epoch 47/200
# 34/34 - 0s - loss: 0.1766 - accuracy: 0.8529 - 109ms/epoch - 3ms/step
# Epoch 48/200
# 34/34 - 0s - loss: 0.1440 - accuracy: 0.9706 - 128ms/epoch - 4ms/step
# Epoch 49/200
# 34/34 - 0s - loss: 0.1074 - accuracy: 0.9706 - 117ms/epoch - 3ms/step
# Epoch 50/200
# 34/34 - 0s - loss: 0.1249 - accuracy: 0.9118 - 109ms/epoch - 3ms/step
# Epoch 51/200
# 34/34 - 0s - loss: 0.1465 - accuracy: 0.9412 - 120ms/epoch - 4ms/step
# Epoch 52/200
# 34/34 - 0s - loss: 0.3901 - accuracy: 0.8529 - 118ms/epoch - 3ms/step
# Epoch 53/200
# 34/34 - 0s - loss: 0.5957 - accuracy: 0.7941 - 99ms/epoch - 3ms/step
# Epoch 54/200
# 34/34 - 0s - loss: 0.2386 - accuracy: 0.9412 - 103ms/epoch - 3ms/step
# Epoch 55/200
# 34/34 - 0s - loss: 0.2237 - accuracy: 0.9118 - 125ms/epoch - 4ms/step
# Epoch 56/200
# 34/34 - 0s - loss: 0.4571 - accuracy: 0.8529 - 124ms/epoch - 4ms/step
# Epoch 57/200
# 34/34 - 0s - loss: 0.2265 - accuracy: 0.9412 - 143ms/epoch - 4ms/step
# Epoch 58/200
# 34/34 - 0s - loss: 0.1842 - accuracy: 0.9706 - 128ms/epoch - 4ms/step
# Epoch 59/200
# 34/34 - 0s - loss: 0.0979 - accuracy: 1.0000 - 116ms/epoch - 3ms/step
# Epoch 60/200
# 34/34 - 0s - loss: 0.0913 - accuracy: 0.9706 - 97ms/epoch - 3ms/step
# Epoch 61/200
# 34/34 - 0s - loss: 0.9853 - accuracy: 0.7647 - 118ms/epoch - 3ms/step
# Epoch 62/200
# 34/34 - 0s - loss: 0.5678 - accuracy: 0.8235 - 123ms/epoch - 4ms/step
# Epoch 63/200
# 34/34 - 0s - loss: 0.2804 - accuracy: 0.8824 - 118ms/epoch - 3ms/step
# Epoch 64/200
# 34/34 - 0s - loss: 0.2193 - accuracy: 0.8824 - 112ms/epoch - 3ms/step
# Epoch 65/200
# 34/34 - 0s - loss: 0.2173 - accuracy: 0.9412 - 133ms/epoch - 4ms/step
# Epoch 66/200
# 34/34 - 0s - loss: 0.1402 - accuracy: 0.9706 - 133ms/epoch - 4ms/step
# Epoch 67/200
# 34/34 - 0s - loss: 0.1125 - accuracy: 0.9412 - 98ms/epoch - 3ms/step
# Epoch 68/200
# 34/34 - 0s - loss: 0.1338 - accuracy: 0.9118 - 119ms/epoch - 3ms/step
# Epoch 69/200
# 34/34 - 0s - loss: 0.9452 - accuracy: 0.7353 - 120ms/epoch - 4ms/step
# Epoch 70/200
# 34/34 - 0s - loss: 0.3989 - accuracy: 0.9706 - 139ms/epoch - 4ms/step
# Epoch 71/200
# 34/34 - 0s - loss: 0.2075 - accuracy: 0.9412 - 144ms/epoch - 4ms/step
# Epoch 72/200
# 34/34 - 0s - loss: 0.1006 - accuracy: 0.9706 - 108ms/epoch - 3ms/step
# Epoch 73/200
# 34/34 - 0s - loss: 0.0851 - accuracy: 0.9706 - 106ms/epoch - 3ms/step
# Epoch 74/200
# 34/34 - 0s - loss: 0.0940 - accuracy: 0.9706 - 126ms/epoch - 4ms/step
# Epoch 75/200
# 34/34 - 0s - loss: 0.0821 - accuracy: 0.9706 - 132ms/epoch - 4ms/step
# Epoch 76/200
# 34/34 - 0s - loss: 0.0692 - accuracy: 0.9706 - 107ms/epoch - 3ms/step
# Epoch 77/200
# 34/34 - 0s - loss: 0.1388 - accuracy: 0.9118 - 105ms/epoch - 3ms/step
# Epoch 78/200
# 34/34 - 0s - loss: 0.0905 - accuracy: 0.9706 - 98ms/epoch - 3ms/step
# Epoch 79/200
# 34/34 - 0s - loss: 0.0712 - accuracy: 0.9412 - 131ms/epoch - 4ms/step
# Epoch 80/200
# 34/34 - 0s - loss: 0.0578 - accuracy: 0.9412 - 120ms/epoch - 4ms/step
# Epoch 81/200
# 34/34 - 0s - loss: 0.0920 - accuracy: 0.9706 - 100ms/epoch - 3ms/step
# Epoch 82/200
# 34/34 - 0s - loss: 0.0522 - accuracy: 0.9706 - 134ms/epoch - 4ms/step
# Epoch 83/200
# 34/34 - 0s - loss: 0.0701 - accuracy: 0.9706 - 96ms/epoch - 3ms/step
# Epoch 84/200
# 34/34 - 0s - loss: 0.6977 - accuracy: 0.8529 - 107ms/epoch - 3ms/step
# Epoch 85/200
# 34/34 - 0s - loss: 0.1677 - accuracy: 0.9118 - 101ms/epoch - 3ms/step
# Epoch 86/200
# 34/34 - 0s - loss: 0.0852 - accuracy: 0.9412 - 96ms/epoch - 3ms/step
# Epoch 87/200
# 34/34 - 0s - loss: 0.0571 - accuracy: 1.0000 - 123ms/epoch - 4ms/step
# Epoch 88/200
# 34/34 - 0s - loss: 0.0453 - accuracy: 0.9706 - 120ms/epoch - 4ms/step
# Epoch 89/200
# 34/34 - 0s - loss: 0.0461 - accuracy: 0.9706 - 107ms/epoch - 3ms/step
# Epoch 90/200
# 34/34 - 0s - loss: 0.0976 - accuracy: 0.9412 - 101ms/epoch - 3ms/step
# Epoch 91/200
# 34/34 - 0s - loss: 0.1127 - accuracy: 0.9412 - 120ms/epoch - 4ms/step
# Epoch 92/200
# 34/34 - 0s - loss: 0.0309 - accuracy: 1.0000 - 102ms/epoch - 3ms/step
# Epoch 93/200
# 34/34 - 0s - loss: 0.0344 - accuracy: 0.9706 - 119ms/epoch - 4ms/step
# Epoch 94/200
# 34/34 - 0s - loss: 0.0305 - accuracy: 1.0000 - 115ms/epoch - 3ms/step
# Epoch 95/200
# 34/34 - 0s - loss: 0.0366 - accuracy: 1.0000 - 131ms/epoch - 4ms/step
# Epoch 96/200
# 34/34 - 0s - loss: 0.0987 - accuracy: 0.9706 - 121ms/epoch - 4ms/step
# Epoch 97/200
# 34/34 - 0s - loss: 0.1352 - accuracy: 0.9706 - 116ms/epoch - 3ms/step
# Epoch 98/200
# 34/34 - 0s - loss: 0.0668 - accuracy: 1.0000 - 88ms/epoch - 3ms/step
# Epoch 99/200
# 34/34 - 0s - loss: 0.0832 - accuracy: 0.9706 - 119ms/epoch - 4ms/step
# Epoch 100/200
# 34/34 - 0s - loss: 0.4256 - accuracy: 0.9118 - 114ms/epoch - 3ms/step
# Epoch 101/200
# 34/34 - 0s - loss: 0.1917 - accuracy: 0.9412 - 114ms/epoch - 3ms/step
# Epoch 102/200
# 34/34 - 0s - loss: 0.4590 - accuracy: 0.8235 - 117ms/epoch - 3ms/step
# Epoch 103/200
# 34/34 - 0s - loss: 0.1687 - accuracy: 0.9706 - 113ms/epoch - 3ms/step
# Epoch 104/200
# 34/34 - 0s - loss: 0.0792 - accuracy: 0.9706 - 139ms/epoch - 4ms/step
# Epoch 105/200
# 34/34 - 0s - loss: 0.0586 - accuracy: 0.9706 - 125ms/epoch - 4ms/step
# Epoch 106/200
# 34/34 - 0s - loss: 0.0481 - accuracy: 0.9706 - 111ms/epoch - 3ms/step
# Epoch 107/200
# 34/34 - 0s - loss: 0.0486 - accuracy: 0.9706 - 121ms/epoch - 4ms/step
# Epoch 108/200
# 34/34 - 0s - loss: 0.0440 - accuracy: 0.9706 - 126ms/epoch - 4ms/step
# Epoch 109/200
# 34/34 - 0s - loss: 0.0483 - accuracy: 0.9706 - 110ms/epoch - 3ms/step
# Epoch 110/200
# 34/34 - 0s - loss: 0.0466 - accuracy: 0.9706 - 121ms/epoch - 4ms/step
# Epoch 111/200
# 34/34 - 0s - loss: 0.0418 - accuracy: 0.9706 - 108ms/epoch - 3ms/step
# Epoch 112/200
# 34/34 - 0s - loss: 0.0442 - accuracy: 0.9706 - 115ms/epoch - 3ms/step
# Epoch 113/200
# 34/34 - 0s - loss: 0.0312 - accuracy: 1.0000 - 140ms/epoch - 4ms/step
# Epoch 114/200
# 34/34 - 0s - loss: 0.0277 - accuracy: 1.0000 - 113ms/epoch - 3ms/step
# Epoch 115/200
# 34/34 - 0s - loss: 0.0343 - accuracy: 0.9706 - 93ms/epoch - 3ms/step
# Epoch 116/200
# 34/34 - 0s - loss: 0.0227 - accuracy: 1.0000 - 109ms/epoch - 3ms/step
# Epoch 117/200
# 34/34 - 0s - loss: 0.0716 - accuracy: 0.9412 - 109ms/epoch - 3ms/step
# Epoch 118/200
# 34/34 - 0s - loss: 0.0325 - accuracy: 0.9706 - 117ms/epoch - 3ms/step
# Epoch 119/200
# 34/34 - 0s - loss: 0.0295 - accuracy: 1.0000 - 109ms/epoch - 3ms/step
# Epoch 120/200
# 34/34 - 0s - loss: 0.0466 - accuracy: 0.9706 - 118ms/epoch - 3ms/step
# Epoch 121/200
# 34/34 - 0s - loss: 0.0138 - accuracy: 1.0000 - 104ms/epoch - 3ms/step
# Epoch 122/200
# 34/34 - 0s - loss: 0.0093 - accuracy: 1.0000 - 116ms/epoch - 3ms/step
# Epoch 123/200
# 34/34 - 0s - loss: 0.0081 - accuracy: 1.0000 - 132ms/epoch - 4ms/step
# Epoch 124/200
# 34/34 - 0s - loss: 0.0051 - accuracy: 1.0000 - 136ms/epoch - 4ms/step
# Epoch 125/200
# 34/34 - 0s - loss: 0.0034 - accuracy: 1.0000 - 125ms/epoch - 4ms/step
# Epoch 126/200
# 34/34 - 0s - loss: 0.0027 - accuracy: 1.0000 - 97ms/epoch - 3ms/step
# Epoch 127/200
# 34/34 - 0s - loss: 0.0023 - accuracy: 1.0000 - 136ms/epoch - 4ms/step
# Epoch 128/200
# 34/34 - 0s - loss: 0.0019 - accuracy: 1.0000 - 115ms/epoch - 3ms/step
# Epoch 129/200
# 34/34 - 0s - loss: 0.0018 - accuracy: 1.0000 - 114ms/epoch - 3ms/step
# Epoch 130/200
# 34/34 - 0s - loss: 0.0015 - accuracy: 1.0000 - 121ms/epoch - 4ms/step
# Epoch 131/200
# 34/34 - 0s - loss: 0.0017 - accuracy: 1.0000 - 104ms/epoch - 3ms/step
# Epoch 132/200
# 34/34 - 0s - loss: 0.0013 - accuracy: 1.0000 - 110ms/epoch - 3ms/step
# Epoch 133/200
# 34/34 - 0s - loss: 8.5869e-04 - accuracy: 1.0000 - 98ms/epoch - 3ms/step
# Epoch 134/200
# 34/34 - 0s - loss: 7.3644e-04 - accuracy: 1.0000 - 114ms/epoch - 3ms/step
# Epoch 135/200
# 34/34 - 0s - loss: 6.7424e-04 - accuracy: 1.0000 - 127ms/epoch - 4ms/step
# Epoch 136/200
# 34/34 - 0s - loss: 6.1370e-04 - accuracy: 1.0000 - 129ms/epoch - 4ms/step
# Epoch 137/200
# 34/34 - 0s - loss: 5.7413e-04 - accuracy: 1.0000 - 114ms/epoch - 3ms/step
# Epoch 138/200
# 34/34 - 0s - loss: 4.9900e-04 - accuracy: 1.0000 - 101ms/epoch - 3ms/step
# Epoch 139/200
# 34/34 - 0s - loss: 4.8327e-04 - accuracy: 1.0000 - 126ms/epoch - 4ms/step
# Epoch 140/200
# 34/34 - 0s - loss: 4.2073e-04 - accuracy: 1.0000 - 118ms/epoch - 3ms/step
# Epoch 141/200
# 34/34 - 0s - loss: 4.1639e-04 - accuracy: 1.0000 - 119ms/epoch - 4ms/step
# Epoch 142/200
# 34/34 - 0s - loss: 3.7865e-04 - accuracy: 1.0000 - 106ms/epoch - 3ms/step
# Epoch 143/200
# 34/34 - 0s - loss: 3.4433e-04 - accuracy: 1.0000 - 124ms/epoch - 4ms/step
# Epoch 144/200
# 34/34 - 0s - loss: 3.1468e-04 - accuracy: 1.0000 - 120ms/epoch - 4ms/step
# Epoch 145/200
# 34/34 - 0s - loss: 3.0571e-04 - accuracy: 1.0000 - 123ms/epoch - 4ms/step
# Epoch 146/200
# 34/34 - 0s - loss: 2.9802e-04 - accuracy: 1.0000 - 116ms/epoch - 3ms/step
# Epoch 147/200
# 34/34 - 0s - loss: 2.5380e-04 - accuracy: 1.0000 - 120ms/epoch - 4ms/step
# Epoch 148/200
# 34/34 - 0s - loss: 2.4934e-04 - accuracy: 1.0000 - 101ms/epoch - 3ms/step
# Epoch 149/200
# 34/34 - 0s - loss: 2.3146e-04 - accuracy: 1.0000 - 100ms/epoch - 3ms/step
# Epoch 150/200
# 34/34 - 0s - loss: 2.1775e-04 - accuracy: 1.0000 - 111ms/epoch - 3ms/step
# Epoch 151/200
# 34/34 - 0s - loss: 2.1425e-04 - accuracy: 1.0000 - 122ms/epoch - 4ms/step
# Epoch 152/200
# 34/34 - 0s - loss: 1.9388e-04 - accuracy: 1.0000 - 112ms/epoch - 3ms/step
# Epoch 153/200
# 34/34 - 0s - loss: 1.9121e-04 - accuracy: 1.0000 - 107ms/epoch - 3ms/step
# Epoch 154/200
# 34/34 - 0s - loss: 1.7359e-04 - accuracy: 1.0000 - 105ms/epoch - 3ms/step
# Epoch 155/200
# 34/34 - 0s - loss: 1.6430e-04 - accuracy: 1.0000 - 118ms/epoch - 3ms/step
# Epoch 156/200
# 34/34 - 0s - loss: 1.6111e-04 - accuracy: 1.0000 - 135ms/epoch - 4ms/step
# Epoch 157/200
# 34/34 - 0s - loss: 1.5642e-04 - accuracy: 1.0000 - 101ms/epoch - 3ms/step
# Epoch 158/200
# 34/34 - 0s - loss: 1.5064e-04 - accuracy: 1.0000 - 120ms/epoch - 4ms/step
# Epoch 159/200
# 34/34 - 0s - loss: 1.4343e-04 - accuracy: 1.0000 - 106ms/epoch - 3ms/step
# Epoch 160/200
# 34/34 - 0s - loss: 1.3487e-04 - accuracy: 1.0000 - 105ms/epoch - 3ms/step
# Epoch 161/200
# 34/34 - 0s - loss: 1.3198e-04 - accuracy: 1.0000 - 110ms/epoch - 3ms/step
# Epoch 162/200
# 34/34 - 0s - loss: 1.2097e-04 - accuracy: 1.0000 - 110ms/epoch - 3ms/step
# Epoch 163/200
# 34/34 - 0s - loss: 1.1951e-04 - accuracy: 1.0000 - 121ms/epoch - 4ms/step
# Epoch 164/200
# 34/34 - 0s - loss: 1.0769e-04 - accuracy: 1.0000 - 129ms/epoch - 4ms/step
# Epoch 165/200
# 34/34 - 0s - loss: 1.0904e-04 - accuracy: 1.0000 - 110ms/epoch - 3ms/step
# Epoch 166/200
# 34/34 - 0s - loss: 1.0164e-04 - accuracy: 1.0000 - 103ms/epoch - 3ms/step
# Epoch 167/200
# 34/34 - 0s - loss: 1.0119e-04 - accuracy: 1.0000 - 116ms/epoch - 3ms/step
# Epoch 168/200
# 34/34 - 0s - loss: 9.7567e-05 - accuracy: 1.0000 - 97ms/epoch - 3ms/step
# Epoch 169/200
# 34/34 - 0s - loss: 8.8769e-05 - accuracy: 1.0000 - 102ms/epoch - 3ms/step
# Epoch 170/200
# 34/34 - 0s - loss: 8.6084e-05 - accuracy: 1.0000 - 115ms/epoch - 3ms/step
# Epoch 171/200
# 34/34 - 0s - loss: 8.3144e-05 - accuracy: 1.0000 - 126ms/epoch - 4ms/step
# Epoch 172/200
# 34/34 - 0s - loss: 8.2047e-05 - accuracy: 1.0000 - 128ms/epoch - 4ms/step
# Epoch 173/200
# 34/34 - 0s - loss: 7.6317e-05 - accuracy: 1.0000 - 130ms/epoch - 4ms/step
# Epoch 174/200
# 34/34 - 0s - loss: 7.4382e-05 - accuracy: 1.0000 - 122ms/epoch - 4ms/step
# Epoch 175/200
# 34/34 - 0s - loss: 6.9518e-05 - accuracy: 1.0000 - 112ms/epoch - 3ms/step
# Epoch 176/200
# 34/34 - 0s - loss: 6.9252e-05 - accuracy: 1.0000 - 87ms/epoch - 3ms/step
# Epoch 177/200
# 34/34 - 0s - loss: 6.8126e-05 - accuracy: 1.0000 - 111ms/epoch - 3ms/step
# Epoch 178/200
# 34/34 - 0s - loss: 6.5256e-05 - accuracy: 1.0000 - 102ms/epoch - 3ms/step
# Epoch 179/200
# 34/34 - 0s - loss: 6.2280e-05 - accuracy: 1.0000 - 116ms/epoch - 3ms/step
# Epoch 180/200
# 34/34 - 0s - loss: 5.7191e-05 - accuracy: 1.0000 - 118ms/epoch - 3ms/step
# Epoch 181/200
# 34/34 - 0s - loss: 5.8344e-05 - accuracy: 1.0000 - 137ms/epoch - 4ms/step
# Epoch 182/200
# 34/34 - 0s - loss: 5.2417e-05 - accuracy: 1.0000 - 108ms/epoch - 3ms/step
# Epoch 183/200
# 34/34 - 0s - loss: 5.1229e-05 - accuracy: 1.0000 - 112ms/epoch - 3ms/step
# Epoch 184/200
# 34/34 - 0s - loss: 5.0293e-05 - accuracy: 1.0000 - 107ms/epoch - 3ms/step
# Epoch 185/200
# 34/34 - 0s - loss: 4.7205e-05 - accuracy: 1.0000 - 118ms/epoch - 3ms/step
# Epoch 186/200
# 34/34 - 0s - loss: 4.7464e-05 - accuracy: 1.0000 - 126ms/epoch - 4ms/step
# Epoch 187/200
# 34/34 - 0s - loss: 4.4078e-05 - accuracy: 1.0000 - 127ms/epoch - 4ms/step
# Epoch 188/200
# 34/34 - 0s - loss: 4.4064e-05 - accuracy: 1.0000 - 123ms/epoch - 4ms/step
# Epoch 189/200
# 34/34 - 0s - loss: 4.3927e-05 - accuracy: 1.0000 - 117ms/epoch - 3ms/step
# Epoch 190/200
# 34/34 - 0s - loss: 4.2921e-05 - accuracy: 1.0000 - 126ms/epoch - 4ms/step
# Epoch 191/200
# 34/34 - 0s - loss: 3.8704e-05 - accuracy: 1.0000 - 123ms/epoch - 4ms/step
# Epoch 192/200
# 34/34 - 0s - loss: 3.8371e-05 - accuracy: 1.0000 - 107ms/epoch - 3ms/step
# Epoch 193/200
# 34/34 - 0s - loss: 3.7926e-05 - accuracy: 1.0000 - 108ms/epoch - 3ms/step
# Epoch 194/200
# 34/34 - 0s - loss: 3.4519e-05 - accuracy: 1.0000 - 133ms/epoch - 4ms/step
# Epoch 195/200
# 34/34 - 0s - loss: 3.6057e-05 - accuracy: 1.0000 - 128ms/epoch - 4ms/step
# Epoch 196/200
# 34/34 - 0s - loss: 3.3138e-05 - accuracy: 1.0000 - 140ms/epoch - 4ms/step
# Epoch 197/200
# 34/34 - 0s - loss: 3.2009e-05 - accuracy: 1.0000 - 127ms/epoch - 4ms/step
# Epoch 198/200
# 34/34 - 0s - loss: 3.2194e-05 - accuracy: 1.0000 - 133ms/epoch - 4ms/step
# Epoch 199/200
# 34/34 - 0s - loss: 3.1010e-05 - accuracy: 1.0000 - 113ms/epoch - 3ms/step
# Epoch 200/200
# 34/34 - 0s - loss: 3.0175e-05 - accuracy: 1.0000 - 119ms/epoch - 3ms/step

# %% [markdown]
# #####학습이 완료되었습니다. 이를 바탕으로 편곡을 진행하겠습니다.

# %%
def arranging_music(model, first_measure, duration): #first_measure: 첫 소절, duration: 생성될 곡의 길이
  music=first_measure
  for i in range(duration):
    p=model.predict(np.float32(np.expand_dims(music[-w:],axis=0)))
    music=np.append(music,[onehot[np.argmax(p)]],axis=0)
  return timeseries2abc(music)

new_song = arranging_music(model, x_train[0], 50)

# %%
print(new_song)
# Out:
# tinynotation: 4/4 c4 c4 g4 g4 a4 a4 g2 f4 f4 e4 e4 d4 d4 c2 g4 g4 f4 f4 e4 e4 d2 g4 g4 f4 f4 e4 e4 d2 c4 c4 g4 g4 a4 a4 g2 f4 f4 e4 e4 d4 d4 c2 g4 g4 f4 f4 e4 e4 d2 g4 g4 f4 f4 e4 e4 d2 c4 c4
